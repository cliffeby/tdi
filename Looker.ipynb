# %%
import looker_sdk
from looker_sdk import models40 
ini_fp = r"C:\dev\Looker_Python\looker.ini"  
sdk = looker_sdk.init40(ini_fp)

# %%
def get_looker_models(ini_fp):
    # sdk = looker_sdk.init40(ini_fp)
    models = sdk.all_lookml_models(fields='name')
    model_names = [model.name for model in models]
    return model_names

def get_field_values(ini_fp, model_name, explore_name):

    # sdk = looker_sdk.init40(ini_fp)

    # API Call to pull in metadata about fields in a particular explore
    explore = sdk.lookml_model_explore(
        lookml_model_name=model_name,
        explore_name=explore_name,
        fields="id, name, description, fields",
    )

    my_fields = []

    # Iterate through the field definitions and pull in the description, sql, and other looker tags to include in data dictionary.
    if explore.fields and explore.fields.dimensions:
        for dimension in explore.fields.dimensions:
            dim_def = {
                "field_type": "Dimension",
                "view_name": dimension.view_label,
                "field_name": dimension.label_short,
                "type": dimension.type,
                "description": dimension.description,
                "sql": dimension.sql,
            }
            my_fields.append(dim_def)
    if explore.fields and explore.fields.measures:
        for measure in explore.fields.measures:
            mes_def = {
                "field_type": "Measure",
                "view_name": measure.view_label,
                "field_name": measure.label_short,
                "type": measure.type,
                "description": measure.description,
                "sql": measure.sql,
            }
            my_fields.append(mes_def)

    return my_fields

def get_explore_fields(ini_fp, model_name, explore_name):
    # sdk = looker_sdk.init40(ini_fp)

    # Retrieve the explore details
    explore = sdk.lookml_model_explore(model_name, explore_name)

    # Extracting the field names
    dimension_names = [dimension.name for dimension in explore.fields.dimensions]
    measure_names = [measure.name for measure in explore.fields.measures]

    return dimension_names + measure_names

def list_explores_for_each_model(ini_fp):
    # sdk = looker_sdk.init40(ini_fp)
    lookml_models = sdk.all_lookml_models(fields='name')
    
    model_explores = {}
    for model in lookml_models:
        explores = sdk.lookml_model(lookml_model_name=model.name, fields='explores')
        model_explores[model.name] = [explore.name for explore in explores.explores]

    return model_explores

def run_query_with_filters_json(ini_fp, model_name, explore_name, fields, filters):
    # sdk = looker_sdk.init40(ini_fp)
    query = {
        "model": model_name,
        "view": explore_name,
        "fields": fields,
    }

    result = sdk.run_inline_query("json", query)
    return result

def run_query_with_filters_csv(ini_fp, model_name, explore_name, fields, filters):
    # sdk = looker_sdk.init40(ini_fp)
    query = {
        "model": model_name,
        "view": explore_name,
        "fields": fields,
    }

    result = sdk.run_inline_query("csv", query)
    return result

model_name = "quantiphi_als_rrv"
explore_name_list = ['subject_data_rrv_2']
explore_name = explore_name_list[0]

print(f"\n\nAvailable Explores: {list_explores_for_each_model(ini_fp)}")
# Out:
# Available Explores: {'quantiphi_als_rrv': ['subject_tracker_data', 'voice_recording_data', 'subject_data_rrv_2'], 'extension-api-explorer': []}

# %%
fields = get_field_values(ini_fp, model_name, explore_name)
print(f"\n\nAvailable Fields for {model_name}: ")
for field in fields:
    print(field)
# Out:
# Available Fields for quantiphi_als_rrv:
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Day of Week', 'type': 'date_day_of_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'ALSFRS Entry Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Days Since Onset', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Days Since Sign Up', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Dynamic Activity', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Dynamic Activity 2', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Cutting Food', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Dressing Hygiene', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Dyspnea', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Handwriting', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Orthopnea', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Respiratory Insufficiency', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Salivation', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Speech', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Swallowing', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Turning in Bed', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'FRS Walking', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Frs Climbing Stairs', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Participant Form ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Total Score', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Data', 'field_name': 'Year Since Signup', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': ' Partial Total (No SSS)', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Als Frs Slope per Month', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Climbing Stairs', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Cutting Food', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Dressing Hygiene', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Dyspnea', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Handwriting', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Orthopnea', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Progression Rate Label', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Respiratory Insufficiency', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Salivation', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Speech', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Swallowing', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Total Score', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Turning In Bed', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSFRS Slope Data', 'field_name': 'Walking', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSoD Gene Category', 'field_name': 'Category', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'ALSoD Gene Category', 'field_name': 'Gene Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Activity Slope La', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Activity Slope Lw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Activity Slope Ra', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Activity Slope Rw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Activity Slope Rwlw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Activity Slope Total', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Slope Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Actual LA', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Actual LW', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Actual RA', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Actual RW', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Actual RWLW', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Actual Total', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Normalized La', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Normalized Lw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Normalized Ra', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Normalized Rw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Normalized Rwlw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Avg Normalized Total', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Days Since Sign Up', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Entry Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Stddev La', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Stddev Lw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Stddev Ra', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Stddev Rw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Stddev Rwlw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Stddev Total', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Total La', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Total Lw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Total Ra', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Total Rw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Total Rwlw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Activity Totals Data', 'field_name': 'Total Total', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': ' 1000 Gp3 Af', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': ' Chr', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'ALSoD Category', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Aaalt', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Aapos', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Aaref', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Clinvar Clnsig', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Clinvar ID', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Clinvar Trait', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'DNA Alt', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'DNA Ref', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Ensembl Geneid', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Ensembl Proteinid', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Ensembl Transcriptid', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Filter', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Gene Name Isolated', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Genotype 1', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Genotype 2', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Hgvsc Snp Eff', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Hgvsc Vep', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Hgvsp Snp Eff', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Hgvsp Vep', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Participant Reference Base', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Polyphen2 Hdiv Pred', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Polyphen2 Hdiv Rankscore', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Polyphen2 Hdiv Score', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Polyphen2 Hvar Pred', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Polyphen2 Hvar Rankscore', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Polyphen2 Hvar Score', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Pos 1 Based ', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Pt. Allele 1 Alt', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Pt. Allele 2 Alt', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Quality', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Sample ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Sift Converted Rankscore', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Sift Pred', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Sift Score', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Uniprot Acc', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'Vep Canonical', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'rsID from Pt. data', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Als Associated Gene Data', 'field_name': 'rsID from dbSNP', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'A/G Ratio', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Albumin (g/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Alkaline Phosphatase (U/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Appointment Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'BUN (mg/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'BUN/Creatinine Ratio', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Basophils (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Basophils Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Bilirubin Total (mg/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'CO2 (MM01/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Calcium (mg/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Chloride (MM01/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Completion Status', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Creatinine (mg/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Days Since Onset', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Days Since Sign Up', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'EGFR (mL/min/1.3 sq m)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Eosinophils (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Eosinophils Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Event ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Globulin (g/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Glucose (mg/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Hematocrit (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Hemoglobin (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'IMM Grans (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'IMM Grans Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Lymphocytes (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Lymphocytes Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'MCH (PB)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'MCHC (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'MCV (FL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Mean Platelet Count (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Monocytes (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Monocytes Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Neutrophils (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Neutrophils Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Nucleated RBC ()/WBC', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Nucleated RBC Abs (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Platelet Count (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Potassium (MM01/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'RDW (%)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Red Blood Cell Count (10^6/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'SGOT (AST) (U/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'SGPT (AST) (U/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Sodium (MM01/L)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'Total Protein (g/dL)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Blood Draw Data', 'field_name': 'White Blood Cell Count (10^3/mm3)', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Date Reported Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'NCT Number', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Joined Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Link', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Clinical Trial Participation', 'field_name': 'Trial Stopped Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Active Ingredient', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Custom Dosage', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Custom Form', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Dosage ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Drug Dosage', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Drug Form', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Drug ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Drug Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'End Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Entry Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Drug Assignment Data', 'field_name': 'Start Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Age At Death', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Age At Sign Up', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Birth Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'C9orf72 Status Self Reported (Yes / No)', 'type': 'yesno', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'C9orf72 Status TDI Reported', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Country', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Current Age', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Days Since Signup', 'type': 'duration_day', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Deceased (Yes / No)', 'type': 'yesno', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Deceased Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Diagnosis', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Drug ID', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Ethnicity', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Family with Als', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Formal Diagnosis Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Formal Diagnosis Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Formal Diagnosis Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Formal Diagnosis Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Formal Diagnosis Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Has 3 or More Data Points (Yes / No)', 'type': 'yesno', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Has Genomic Data (Yes / No)', 'type': 'yesno', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Age', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Day of Week', 'type': 'date_day_of_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Site', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Onset Site Unnested', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Participant Type', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Possible Diagnosis Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Possible Diagnosis Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Possible Diagnosis Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Possible Diagnosis Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Possible Diagnosis Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Region', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sex', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Day of Week', 'type': 'date_day_of_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Sign Up Date Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Total ALSFRS', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Total Blood Draw', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Total Tracker', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Total Voice Recording', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Data', 'field_name': 'Years Since Signup', 'type': 'duration_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Participant Status Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Created Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Protocol Status Data', 'field_name': 'Protocol Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Assigned Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Given Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Return Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Return Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Return Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Participant Tracker Data', 'field_name': 'Date Return Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# ...
# {'field_type': 'Dimension', 'view_name': 'Supplement Assignment Data', 'field_name': 'Supplement Assignment Frequency', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Supplement Assignment Data', 'field_name': 'Supplement Brand Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Supplement Assignment Data', 'field_name': 'Supplement ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Supplement Assignment Data', 'field_name': 'Supplement Net Content Unit', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Supplement Assignment Data', 'field_name': 'Supplement Net Contents', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Supplement Assignment Data', 'field_name': 'Supplement Product Name', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Answer ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Answer Value', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Date Submitted Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Parent Question Title', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Question ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Question Title', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Response ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Response Route', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Survey Data', 'field_name': 'Survey Title', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'End Time Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Start Time Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Tracker Exercise Isolations', 'field_name': 'Subject Tracker ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Date', 'type': 'date_date', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Month', 'type': 'date_month', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Quarter', 'type': 'date_quarter', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Raw', 'type': 'date_raw', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Time', 'type': 'date_time', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Week', 'type': 'date_week', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Date Completed Year', 'type': 'date_year', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Days Since Onset From Recording', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Days Since Sign Up From Recording', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'File Mp3', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'File Wav', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Participant ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Phrases', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Recording ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data', 'field_name': 'Score', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data: Phrases', 'field_name': 'Phrase ID', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data: Phrases', 'field_name': 'Phrase Text', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data: Phrases', 'field_name': 'Recording Phrase Order', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Dimension', 'view_name': 'Voice Recording Data: Phrases', 'field_name': 'Voice Recording Data Phrases', 'type': 'string', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'ALSFRS Data', 'field_name': 'Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'ALSFRS Data', 'field_name': 'Days Since Sign Up', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'ALSFRS Data', 'field_name': 'Dynamic Activity Sum', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'ALSFRS Data', 'field_name': 'Dynamic Activity Sum 2', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'ALSFRS Data', 'field_name': 'Total ALSFRS Score', 'type': 'average_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'ALSFRS Data', 'field_name': 'Years Since Sign Up', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Average Actual LA', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Average Actual LW', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Average Actual RA', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Average Actual RW', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Average Actual RWLW', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Average Actual Total', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'La Avg Normalized', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Lw Avg Normalized', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Participant ID Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Ra Avg Normalized', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Rw Avg Normalized', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Rwlw Avg Normalized', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Total La', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Total Lw', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Total Ra', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Total Rw', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Total Rwlw', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Activity Totals Data', 'field_name': 'Total total', 'type': 'sum_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Als Associated Gene Data', 'field_name': 'Count of Genomes', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Als Associated Gene Data', 'field_name': 'Count of Participants', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Als Associated Gene Data', 'field_name': 'Mutation Count By Gene', 'type': 'number', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Drug Assignment Data', 'field_name': 'Count of Participants', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Drug Assignment Data', 'field_name': 'Drug Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Count', 'type': 'count', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Count of Genome', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Drug ID Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Gender Female', 'type': 'count', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Gender Male', 'type': 'count', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Number of Countries', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Number of Ethnicities', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Onset Age Avg', 'type': 'average', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Onset Age Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Onset Site Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Participant ID Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Participant Protocol Status Data Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Region Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Total ALSFRS Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Total Als Frs Avg', 'type': 'average', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Total Blood Draw Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Total Tracker Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Participant Data', 'field_name': 'Total Voice Recording Count', 'type': 'count_distinct', 'description': '', 'sql': None}
# {'field_type': 'Measure', 'view_name': 'Voice Recording Data', 'field_name': 'Score', 'type': 'average_distinct', 'description': '', 'sql': None}

# %%
field_names = get_explore_fields(ini_fp, model_name, explore_name)
print("\n\nAvailable Field Names: ")
for name in field_names:
    print(name)
# Out:
# Available Field Names:
# als_frs_data.subject_form_entry_date
# als_frs_data.subject_form_entry_day_of_week
# als_frs_data.subject_form_entry_month
# als_frs_data.subject_form_entry_quarter
# als_frs_data.subject_form_entry_raw
# als_frs_data.subject_form_entry_time
# als_frs_data.subject_form_entry_week
# als_frs_data.subject_form_entry_year
# als_frs_data.days_since_onset
# als_frs_data.days_since_sign_up
# als_frs_data.dynamic_activity
# als_frs_data.dynamic_activity_2
# als_frs_data.frs_cutting_food
# als_frs_data.frs_dressing_hygiene
# als_frs_data.frs_dyspnea
# als_frs_data.frs_handwriting
# als_frs_data.frs_orthopnea
# als_frs_data.frs_respiratory_insufficiency
# als_frs_data.frs_salivation
# als_frs_data.frs_speech
# als_frs_data.frs_swallowing
# als_frs_data.frs_turning_in_bed
# als_frs_data.frs_walking
# als_frs_data.frs_climbing_stairs
# als_frs_data.subject_form_id
# als_frs_data.subject_id
# als_frs_data.total_score
# als_frs_data.year_since_signup
# als_frs_slope_data.partial_total
# als_frs_slope_data.als_frs_slope_per_month
# als_frs_slope_data.climbing_stairs
# als_frs_slope_data.cutting_food
# als_frs_slope_data.dressing_hygiene
# als_frs_slope_data.dyspnea
# als_frs_slope_data.handwriting
# als_frs_slope_data.orthopnea
# als_frs_slope_data.subject_id
# als_frs_slope_data.progression_rate
# als_frs_slope_data.respiratory_insufficiency
# als_frs_slope_data.salivation
# als_frs_slope_data.speech
# als_frs_slope_data.swallowing
# als_frs_slope_data.total
# als_frs_slope_data.turning_in_bed
# als_frs_slope_data.walking
# alsod_gene_category.category
# alsod_gene_category.gene_name
# activity_slope_data.activity_slope_la
# activity_slope_data.activity_slope_lw
# activity_slope_data.activity_slope_ra
# activity_slope_data.activity_slope_rw
# activity_slope_data.activity_slope_rwlw
# activity_slope_data.activity_slope_total
# activity_slope_data.subject_id
# activity_totals_data.avg_la
# activity_totals_data.avg_lw
# activity_totals_data.avg_ra
# activity_totals_data.avg_rw
# activity_totals_data.avg_rwlw
# activity_totals_data.avg_total
# activity_totals_data.avg_normalized_la
# activity_totals_data.avg_normalized_lw
# activity_totals_data.avg_normalized_ra
# activity_totals_data.avg_normalized_rw
# activity_totals_data.avg_normalized_rwlw
# activity_totals_data.avg_normalized_total
# activity_totals_data.number_of_days
# activity_totals_data.entry_date
# activity_totals_data.entry_month
# activity_totals_data.entry_quarter
# activity_totals_data.entry_raw
# activity_totals_data.entry_time
# activity_totals_data.entry_week
# activity_totals_data.entry_year
# activity_totals_data.subject_id
# activity_totals_data.stddev_la
# activity_totals_data.stddev_lw
# activity_totals_data.stddev_ra
# activity_totals_data.stddev_rw
# activity_totals_data.stddev_rwlw
# activity_totals_data.stddev_total
# activity_totals_data.total_la
# activity_totals_data.total_lw
# activity_totals_data.total_ra
# activity_totals_data.total_rw
# activity_totals_data.total_rwlw
# activity_totals_data.total_total
# als_associated_gene_data._1000_gp3_af
# als_associated_gene_data._chr
# als_associated_gene_data.alsod_category
# als_associated_gene_data.aaalt
# als_associated_gene_data.aapos
# als_associated_gene_data.aaref
# als_associated_gene_data.clinvar_clnsig
# als_associated_gene_data.clinvar_id
# als_associated_gene_data.clinvar_trait
# als_associated_gene_data.alt
# als_associated_gene_data.ref
# als_associated_gene_data.ensembl_geneid
# als_associated_gene_data.ensembl_proteinid
# als_associated_gene_data.ensembl_transcriptid
# als_associated_gene_data.filter
# als_associated_gene_data.genenamei
# als_associated_gene_data.genotype_1
# als_associated_gene_data.genotype_2
# als_associated_gene_data.hgvsc_snp_eff
# als_associated_gene_data.hgvsc_vep
# als_associated_gene_data.hgvsp_snp_eff
# als_associated_gene_data.hgvsp_vep
# als_associated_gene_data.subject_id
# als_associated_gene_data.reference_bases
# als_associated_gene_data.polyphen2_hdiv_pred
# als_associated_gene_data.polyphen2_hdiv_rankscore
# als_associated_gene_data.polyphen2_hdiv_score
# als_associated_gene_data.polyphen2_hvar_pred
# als_associated_gene_data.polyphen2_hvar_rankscore
# als_associated_gene_data.polyphen2_hvar_score
# als_associated_gene_data.pos_1_based_
# als_associated_gene_data.base_alt_1
# als_associated_gene_data.base_alt_2
# als_associated_gene_data.quality
# als_associated_gene_data.sample_id
# als_associated_gene_data.sift_converted_rankscore
# als_associated_gene_data.sift_pred
# als_associated_gene_data.sift_score
# als_associated_gene_data.uniprot_acc
# als_associated_gene_data.vep_canonical
# als_associated_gene_data.names
# als_associated_gene_data.rs_db_snp
# blood_draw_data.ag_ratio
# blood_draw_data.albumin
# blood_draw_data.alkaline_phosphatase
# blood_draw_data.appointment_date
# blood_draw_data.appointment_month
# blood_draw_data.appointment_quarter
# blood_draw_data.appointment_raw
# blood_draw_data.appointment_time
# blood_draw_data.appointment_week
# blood_draw_data.appointment_year
# blood_draw_data.bun
# blood_draw_data.bun_creatinine_ratio
# blood_draw_data.basophils
# blood_draw_data.basophils_abs
# blood_draw_data.bilirubin_total
# blood_draw_data.co2
# blood_draw_data.calcium
# blood_draw_data.chloride
# blood_draw_data.completion_status
# blood_draw_data.creatinine_serum
# blood_draw_data.days_since_onset
# blood_draw_data.days_since_sign_up
# blood_draw_data.egfr
# blood_draw_data.eosinophils
# blood_draw_data.eosinophils_abs
# blood_draw_data.subject_event_id
# blood_draw_data.globulin
# blood_draw_data.glucose
# blood_draw_data.hematocrit
# blood_draw_data.hemoglobin
# blood_draw_data.imm_grans
# blood_draw_data.imm_grans_abs
# blood_draw_data.lymphocytes
# blood_draw_data.lymphocytes_abs
# blood_draw_data.mch
# blood_draw_data.mchc
# blood_draw_data.mcv
# blood_draw_data.mean_platelet_count
# blood_draw_data.monocytes
# blood_draw_data.monocytes_abs
# blood_draw_data.neutrophils
# blood_draw_data.neutrophils_abs
# blood_draw_data.nucleated_rbc
# blood_draw_data.nucleated_rbc_abs
# blood_draw_data.subject_id
# blood_draw_data.platelet_count
# blood_draw_data.potassium
# blood_draw_data.rdw
# blood_draw_data.red_blood_cell_count
# blood_draw_data.sgot
# blood_draw_data.sgpt
# blood_draw_data.sodium
# blood_draw_data.total_protein
# blood_draw_data.white_blood_cell_count
# clinical_trial_data.clinical_trial_assignment_date_modified_date
# clinical_trial_data.clinical_trial_assignment_date_modified_month
# clinical_trial_data.clinical_trial_assignment_date_modified_quarter
# clinical_trial_data.clinical_trial_assignment_date_modified_raw
# clinical_trial_data.clinical_trial_assignment_date_modified_time
# clinical_trial_data.clinical_trial_assignment_date_modified_week
# clinical_trial_data.clinical_trial_assignment_date_modified_year
# clinical_trial_data.clinical_trial_gov_id
# clinical_trial_data.subject_id
# clinical_trial_data.clinical_trial_assignment_start_date_date
# clinical_trial_data.clinical_trial_assignment_start_date_month
# clinical_trial_data.clinical_trial_assignment_start_date_quarter
# clinical_trial_data.clinical_trial_assignment_start_date_raw
# clinical_trial_data.clinical_trial_assignment_start_date_time
# clinical_trial_data.clinical_trial_assignment_start_date_week
# clinical_trial_data.clinical_trial_assignment_start_date_year
# clinical_trial_data.clinical_trial_link_to_protocol_online
# clinical_trial_data.clinical_trial_name
# clinical_trial_data.clinical_trial_assignment_end_date_date
# clinical_trial_data.clinical_trial_assignment_end_date_month
# clinical_trial_data.clinical_trial_assignment_end_date_quarter
# clinical_trial_data.clinical_trial_assignment_end_date_raw
# clinical_trial_data.clinical_trial_assignment_end_date_time
# clinical_trial_data.clinical_trial_assignment_end_date_week
# clinical_trial_data.clinical_trial_assignment_end_date_year
# drug_assignment_data.drug_active_ingredient
# drug_assignment_data.drug_assignment_custom_dosage
# drug_assignment_data.drug_assignment_custom_form
# drug_assignment_data.dosage_id
# drug_assignment_data.drug_dosage_dosage
# drug_assignment_data.drug_dosage_form
# drug_assignment_data.drug_id
# drug_assignment_data.drug_name
# drug_assignment_data.drug_assignment_end_date
# drug_assignment_data.drug_assignment_end_month
# drug_assignment_data.drug_assignment_end_quarter
# drug_assignment_data.drug_assignment_end_raw
# drug_assignment_data.drug_assignment_end_time
# drug_assignment_data.drug_assignment_end_week
# drug_assignment_data.drug_assignment_end_year
# drug_assignment_data.drug_assignment_date_created_date
# drug_assignment_data.drug_assignment_date_created_month
# drug_assignment_data.drug_assignment_date_created_quarter
# drug_assignment_data.drug_assignment_date_created_raw
# drug_assignment_data.drug_assignment_date_created_time
# drug_assignment_data.drug_assignment_date_created_week
# drug_assignment_data.drug_assignment_date_created_year
# drug_assignment_data.subject_id
# drug_assignment_data.drug_assignment_start_date
# drug_assignment_data.drug_assignment_start_month
# drug_assignment_data.drug_assignment_start_quarter
# drug_assignment_data.drug_assignment_start_raw
# drug_assignment_data.drug_assignment_start_time
# drug_assignment_data.drug_assignment_start_week
# drug_assignment_data.drug_assignment_start_year
# subject_data_rrv_2.age_at_death
# subject_data_rrv_2.age_at_sign_up
# subject_data_rrv_2.birth_date_year
# subject_data_rrv_2.C9orf72_status_self_reported
# subject_data_rrv_2.C9orf72_status_TDI_reported
# subject_data_rrv_2.country
# subject_data_rrv_2.current_age
# subject_data_rrv_2.days_since_signup
# subject_data_rrv_2.deceased
# subject_data_rrv_2.death_date_year
# subject_data_rrv_2.diagnosis
# subject_data_rrv_2.drug_id
# subject_data_rrv_2.ethnicity
# subject_data_rrv_2.family_with_als
# subject_data_rrv_2.formal_diagnosis_date_date
# subject_data_rrv_2.formal_diagnosis_date_month
# subject_data_rrv_2.formal_diagnosis_date_quarter
# subject_data_rrv_2.formal_diagnosis_date_raw
# subject_data_rrv_2.formal_diagnosis_date_year
# subject_data_rrv_2.has_3_or_more_data_points
# subject_data_rrv_2.has_genomic_data
# subject_data_rrv_2.onset_age
# subject_data_rrv_2.onset_date_date
# subject_data_rrv_2.onset_date_day_of_week
# subject_data_rrv_2.onset_date_month
# subject_data_rrv_2.onset_date_quarter
# subject_data_rrv_2.onset_date_raw
# subject_data_rrv_2.onset_date_time
# subject_data_rrv_2.onset_date_week
# subject_data_rrv_2.onset_date_year
# subject_data_rrv_2.onset_site
# subject_data_rrv_2.onset_site_unnested
# subject_data_rrv_2.subject_id
# subject_data_rrv_2.participant_type
# subject_data_rrv_2.possible_diagnosis_date_date
# subject_data_rrv_2.possible_diagnosis_date_month
# subject_data_rrv_2.possible_diagnosis_date_quarter
# subject_data_rrv_2.possible_diagnosis_date_raw
# subject_data_rrv_2.possible_diagnosis_date_year
# subject_data_rrv_2.region
# subject_data_rrv_2.gender
# subject_data_rrv_2.sign_up_date_date
# subject_data_rrv_2.sign_up_date_day_of_week
# subject_data_rrv_2.sign_up_date_month
# subject_data_rrv_2.sign_up_date_quarter
# subject_data_rrv_2.sign_up_date_raw
# subject_data_rrv_2.sign_up_date_time
# subject_data_rrv_2.sign_up_date_week
# subject_data_rrv_2.sign_up_date_year
# subject_data_rrv_2.total_als_frs
# subject_data_rrv_2.total_blood_draw
# subject_data_rrv_2.total_tracker
# subject_data_rrv_2.total_voice_recording
# subject_data_rrv_2.years_since_signup
# subject_protocol_status_data.subject_id
# subject_protocol_status_data.subject_status_name
# subject_protocol_status_data.protocol_created_date
# subject_protocol_status_data.protocol_created_month
# subject_protocol_status_data.protocol_created_quarter
# subject_protocol_status_data.protocol_created_raw
# subject_protocol_status_data.protocol_created_time
# subject_protocol_status_data.protocol_created_week
# subject_protocol_status_data.protocol_created_year
# subject_protocol_status_data.protocol_name
# subject_tracker_data.assigned_date
# subject_tracker_data.assigned_month
# subject_tracker_data.assigned_quarter
# subject_tracker_data.assigned_raw
# subject_tracker_data.assigned_time
# subject_tracker_data.assigned_week
# subject_tracker_data.assigned_year
# subject_tracker_data.date_given_date
# subject_tracker_data.date_given_month
# subject_tracker_data.date_given_quarter
# subject_tracker_data.date_given_raw
# subject_tracker_data.date_given_time
# subject_tracker_data.date_given_week
# subject_tracker_data.date_given_year
# subject_tracker_data.date_return_date
# subject_tracker_data.date_return_month
# subject_tracker_data.date_return_quarter
# subject_tracker_data.date_return_raw
# subject_tracker_data.date_return_time
# subject_tracker_data.date_return_week
# subject_tracker_data.date_return_year
# subject_tracker_data.isolations
# subject_tracker_data.limb_assignment
# subject_tracker_data.overrides
# subject_tracker_data.subject_id
# subject_tracker_data.subject_tracker_id
# subject_tracker_data.tracker_id
# subject_tracker_data.tracker_serial_number
# genomic_silver_layer_part.filter
# genomic_silver_layer_part.genotype_1
# genomic_silver_layer_part.genotype_2
# genomic_silver_layer_part.subject_id
# genomic_silver_layer_part.base_alt_1
# genomic_silver_layer_part.base_alt_2
# genomic_silver_layer_part.reference_bases
# genomic_silver_layer_part.quality
# genomic_silver_layer_part.sample_id
# genomic_silver_layer_part.names
# stranalysis.allele_1_max_confidence_interval
# stranalysis.allele_1_min_confidence_interval
# stranalysis.allele_1_repeat_count
# stranalysis.allele_1_repeat_status
# stranalysis.allele_2_max_confidence_interval
# stranalysis.allele_2_min_confidence_interval
# stranalysis.allele_2_repeat_count
# stranalysis.allele_2_repeat_status
# stranalysis.coverage
# stranalysis.disease
# stranalysis.intermediate
# stranalysis.location
# stranalysis.normal
# stranalysis.notes
# stranalysis.participant_id
# stranalysis.Pathogenic
# stranalysis.reference_region__hg19_
# stranalysis.reference_region__hg38_
# stranalysis.repeat_type
# stranalysis.repeat_unit
# stranalysis.str_gene
# stranalysis.stripy_url
# supplement_assignment_data.supplement_assignment_custom_serving_size_quantity
# supplement_assignment_data.supplement_assignment_custom_serving_size_unit
# supplement_assignment_data.supplement_assignment_end_date
# supplement_assignment_data.supplement_assignment_end_month
# supplement_assignment_data.supplement_assignment_end_quarter
# supplement_assignment_data.supplement_assignment_end_raw
# supplement_assignment_data.supplement_assignment_end_time
# supplement_assignment_data.supplement_assignment_end_week
# supplement_assignment_data.supplement_assignment_end_year
# supplement_assignment_data.subject_id
# supplement_assignment_data.supplement_serving_size_quantity
# supplement_assignment_data.supplement_serving_size_unit
# supplement_assignment_data.supplement_assignment_start_date
# supplement_assignment_data.supplement_assignment_start_month
# supplement_assignment_data.supplement_assignment_start_quarter
# supplement_assignment_data.supplement_assignment_start_raw
# supplement_assignment_data.supplement_assignment_start_time
# supplement_assignment_data.supplement_assignment_start_week
# supplement_assignment_data.supplement_assignment_start_year
# supplement_assignment_data.supplement_assignment_frequency
# supplement_assignment_data.supplement_brand_name
# supplement_assignment_data.supplement_id
# supplement_assignment_data.supplement_net_content_unit
# supplement_assignment_data.supplement_net_contents
# supplement_assignment_data.supplement_product_name
# survey_data.answer_id
# survey_data.answer_value
# survey_data.date_submitted_date
# survey_data.date_submitted_month
# survey_data.date_submitted_quarter
# survey_data.date_submitted_raw
# survey_data.date_submitted_time
# survey_data.date_submitted_week
# survey_data.date_submitted_year
# survey_data.parent_question_title
# survey_data.subject_id
# survey_data.question_id
# survey_data.question_title
# survey_data.response_id
# survey_data.answer_pipe
# survey_data.survey_title
# tracker_exercise_isolations.end_time_date
# tracker_exercise_isolations.end_time_month
# tracker_exercise_isolations.end_time_quarter
# tracker_exercise_isolations.end_time_raw
# tracker_exercise_isolations.end_time_time
# tracker_exercise_isolations.end_time_week
# tracker_exercise_isolations.end_time_year
# tracker_exercise_isolations.start_time_date
# tracker_exercise_isolations.start_time_month
# tracker_exercise_isolations.start_time_quarter
# tracker_exercise_isolations.start_time_raw
# tracker_exercise_isolations.start_time_time
# tracker_exercise_isolations.start_time_week
# tracker_exercise_isolations.start_time_year
# tracker_exercise_isolations.subject_tracker_id
# voice_recording_data.date_completed_date
# voice_recording_data.date_completed_month
# voice_recording_data.date_completed_quarter
# voice_recording_data.date_completed_raw
# voice_recording_data.date_completed_time
# voice_recording_data.date_completed_week
# voice_recording_data.date_completed_year
# voice_recording_data.days_since_onset
# voice_recording_data.days_since_sign_up
# voice_recording_data.file_mp3
# voice_recording_data.file_wav
# voice_recording_data.subject_id
# voice_recording_data.phrases
# voice_recording_data.recording_id
# voice_recording_data.score
# voice_recording_data__phrases.phrase_id
# voice_recording_data__phrases.phrase_text
# voice_recording_data__phrases.recording_phrase_order
# voice_recording_data__phrases.voice_recording_data__phrases
# als_frs_data.count
# als_frs_data.total_days_signup
# als_frs_data.dynamic_activity_sum
# als_frs_data.dynamic_activity_sum_2
# als_frs_data.total_score_alsfrs_r
# als_frs_data.total_year_signup
# activity_totals_data.average_la
# activity_totals_data.average_lw
# activity_totals_data.average_ra
# activity_totals_data.average_rw
# activity_totals_data.average_rwlw
# activity_totals_data.average_total
# activity_totals_data.count
# activity_totals_data.la_avg_normalized
# activity_totals_data.lw_avg_normalized
# activity_totals_data.count_subjectid
# activity_totals_data.ra_avg_normalized
# activity_totals_data.rw_avg_normalized
# activity_totals_data.rwlw_avg_normalized
# activity_totals_data.total_la_agg
# activity_totals_data.total_lw_agg
# activity_totals_data.total_ra_agg
# activity_totals_data.total_rw_agg
# activity_totals_data.total_rwlw_agg
# activity_totals_data.total_total_agg
# als_associated_gene_data.count_of_genomes
# als_associated_gene_data.count_of_participants
# als_associated_gene_data.mutation_count_by_gene
# drug_assignment_data.count_of_participants
# drug_assignment_data.count_drugid
# subject_data_rrv_2.count
# subject_data_rrv_2.count_of_genome
# subject_data_rrv_2.drug_id_count
# subject_data_rrv_2.gender_female
# subject_data_rrv_2.gender_male
# subject_data_rrv_2.country_count
# subject_data_rrv_2.ethnicity_count
# subject_data_rrv_2.onset_age_avg
# subject_data_rrv_2.onset_age_count
# subject_data_rrv_2.onset_site_count
# subject_data_rrv_2.subject_id_count
# subject_data_rrv_2.subject_protocol_status_data_count
# subject_data_rrv_2.region_count
# subject_data_rrv_2.total_als_frs_count
# subject_data_rrv_2.total_als_frs_avg
# subject_data_rrv_2.total_blood_draw_count
# subject_data_rrv_2.total_tracker_count
# subject_data_rrv_2.total_voice_recording_count
# voice_recording_data.score_score

# %%
# # Example filter dict:
# filters = {
#     "field_name1": "filter_value1",
#     "field_name2": "filter_value2",
#     # Add as many field filters as needed
# }
filters = {}

# Example: query using the first ten fields returned
# fields.pop(11)
fields = field_names[0:20]
data = run_query_with_filters_csv(ini_fp, model_name, explore_name, fields, filters=filters)
print("\n\n")
print(data)
# Out:
# ---------------------------------------------------------------------------
# SDKError                                  Traceback (most recent call last)
# Cell In[83], line 12
#       9 # Example: query using the first ten fields returned
#      10 # fields.pop(11)
#      11 fields = field_names[0:20]
# ---> 12 data = run_query_with_filters_csv(ini_fp, model_name, explore_name, fields, filters=filters)
#      13 print("\n\n")
#      14 print(data)
#
# Cell In[80], line 88, in run_query_with_filters_csv(ini_fp, model_name, explore_name, fields, filters)
#      80 def run_query_with_filters_csv(ini_fp, model_name, explore_name, fields, filters):
#      81     # sdk = looker_sdk.init40(ini_fp)
#      82     query = {
#      83         "model": model_name,
#      84         "view": explore_name,
#      85         "fields": fields,
#      86     }
# ---> 88     result = sdk.run_inline_query("csv", query)
#      89     return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\looker_sdk\sdk\api40\methods.py:9222, in Looker40SDK.run_inline_query(self, result_format, body, limit, apply_formatting, apply_vis, cache, image_width, image_height, generate_drill_links, force_production, cache_only, path_prefix, rebuild_pdts, server_table_calcs, transport_options)
#    9218 """Run Inline Query"""
#    9219 result_format = self.encode_path_param(result_format)
#    9220 response = cast(
#    9221     Union[str, bytes],
# -> 9222     self.post(
#    9223         path=f"/queries/run/{result_format}",
#    9224         structure=Union[str, bytes],  # type: ignore
#    9225         query_params={
#    9226             "limit": limit,
#    9227             "apply_formatting": apply_formatting,
#    9228             "apply_vis": apply_vis,
#    9229             "cache": cache,
#    9230             "image_width": image_width,
#    9231             "image_height": image_height,
#    9232             "generate_drill_links": generate_drill_links,
#    9233             "force_production": force_production,
#    9234             "cache_only": cache_only,
#    9235             "path_prefix": path_prefix,
#    9236             "rebuild_pdts": rebuild_pdts,
#    9237             "server_table_calcs": server_table_calcs,
#    9238         },
#    9239         body=body,
#    9240         transport_options=transport_options,
#    9241     ),
#    9242 )
#    9243 return response
#
# File ~\AppData\Roaming\Python\Python312\site-packages\looker_sdk\rtl\api_methods.py:188, in APIMethods.post(self, path, structure, query_params, body, transport_options)
#     179 serialized = self._get_serialized(body)
#     180 response = self.transport.request(
#     181     transport.HttpMethod.POST,
#     182     self._path(path),
#    (...)
#     186     transport_options=transport_options,
#     187 )
# --> 188 return self._return(response, structure)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\looker_sdk\rtl\api_methods.py:101, in APIMethods._return(self, response, structure)
#      99     except serialize.DeserializeError:
#     100         raise error.SDKError(value)
# --> 101     raise sdk_error
#     102 ret: TReturn
#     103 if structure is None:
#
# SDKError:
#     message:           Query execution failed:  - Name AS not found inside als_frs_data at [13:20]
#     documentation_url: https://cloud.google.com/looker/docs/r/err/4.0/400/post/queries/run/:result_format
#     error_doc_url:     https://static-a.cdn.looker.app/errorcodes/400.md
#     error details:

# %%
# Initialize the SDK (use init31() for the older v3.1 API)
# sdk = looker_sdk.init40()

# Get information about the authenticated user
my_user = sdk.me()

instance_url = sdk.get_setting(fields="host_url")
print(instance_url['host_url'])

# Output can be treated like a dictionary
print(my_user["first_name"])

# Or as a model instance (User in this case)
print(my_user.first_name)
# Out:
# https://alstdi.cloud.looker.com
# Clifford
# Clifford

# %%
"""
This script will construct and output an object detailing content access metadata for each folder, 
providing an example of how to recursively traverse the folder tree. For each folder, the object will
contain a list of Groups and Users who have either been explicitly been granted view/edit access to 
the folder, or implicitly given via inheritence from a parent folder.

To include personal and/or the embed shared folders, modify the parameters below. 
"""

# import looker_sdk
import pprint as pp

# sdk = looker_sdk.init40()

# includes both folders under folders/users "People" folder and folders/embed_users "Embed Users"
INCLUDE_PERSONAL = False
# include folders under folders/embed_shared "Embed Groups" folder
INCLUDE_EMBED_SHARED = False


def get_folders():
    print('** gathering folder info **')
    all_folders = sdk.all_folders()  # get all folder metadata
    folder_access = {}

    for f in all_folders:
        personal = f.is_personal or f.is_personal_descendant
        if (personal or f.is_users_root or f.is_embed_users_root) and not INCLUDE_PERSONAL:
            continue
        if (not personal and f.is_embed) and not INCLUDE_EMBED_SHARED:
            continue
        folder_access[f.id] = {"folder_id": f.id,
                               "name": f.name,
                               "parent_id": f.parent_id,
                               "content_metadata_id": f.content_metadata_id,
                               "personal": personal,
                               "child_count": f.child_count}

    folder_access.pop('lookml')  # remove lookml dashboard folder
    return folder_access


def grab_folder_permissions(f: str, folders: object):
    print('checking folder: {}'.format(f))

    if 'access' in folders[f]:
        print('skipping folder {}: already have access details'.format(f))
    else:
        # groups / users can view / edit in folder (content_metadata_id)
        cmgu = sdk.all_content_metadata_accesses(
            content_metadata_id=folders[f]["content_metadata_id"], fields='group_id,user_id,permission_type')

        access = {"groups": [], "users": []}
        access["groups"] = [{"id": i.group_id, "permission_type": i.permission_type.value}
                            for i in cmgu if i.group_id is not None]
        access["users"] = [{"id": i.user_id, "permission_type": i.permission_type.value}
                           for i in cmgu if i.user_id is not None]
        folders[f]['access'] = access

    # folders / dash / looks in folder (content_metadata_id). use to check if folder 'inherits' content access
    cm = sdk.all_content_metadatas(
        parent_id=folders[f]['content_metadata_id'], fields='folder_id,inherits')

    # add access to all inheriting folders
    for c in cm:
        if c.folder_id is not None:
            try:
                if c.inherits:
                    print('{} inherits as parent {}'.format(c.folder_id, f))
                    folders[c.folder_id]['access'] = folders[f]['access']
                # recursively set child folders (depth first)
                grab_folder_permissions(c.folder_id, folders)
            except:
                # most likely the folder has been deleted
                print('skipping folder {}: no access data'.format(c.folder_id))

    return folders


def main():
    """Construct a dictionary of folder objects with access permissions:

    folder_id: {
        folder_id: string
        name: string
        parent_id: string
        content_metadata_id: string
        personal: bool based on is_personal or is_personal_descendant
        child_count: number of folders inside the folder
        access: {groups:[{id: int,permission_type: 'view' | 'edit'}], users:[{id: int,permission_type: 'view' | 'edit'}]}
    }

    admins have access to all content folders and are not included"""

    folders = get_folders()
    print('** gathering shared folders **')
    folder_access = grab_folder_permissions(
        '1', folders)  # start at folders/home
    if INCLUDE_PERSONAL or INCLUDE_EMBED_SHARED:
        print('** gathering personal and/or embed folders **')
        for f in folders:
            if 'access' not in folders[f]:
                folder_access = grab_folder_permissions(f, folders)

    pp.pprint(folder_access, sort_dicts=False)


main()
# Out:
# ** gathering folder info **
# ** gathering shared folders **
# checking folder: 1
# 8 inherits as parent 1
# skipping folder 8: no access data
# 29 inherits as parent 1
# checking folder: 29
# skipping folder 29: already have access details
# {'1': {'folder_id': '1',
#        'name': 'Shared',
#        'parent_id': None,
#        'content_metadata_id': '1',
#        'personal': False,
#        'child_count': 1,
#        'access': {'groups': [{'id': '1', 'permission_type': 'edit'}],
#                   'users': []}},
#  '29': {'folder_id': '29',
#         'name': 'Main ALSTDI Dashboards',
#         'parent_id': '1',
#         'content_metadata_id': '125',
#         'personal': False,
#         'child_count': 0,
#         'access': {'groups': [{'id': '1', 'permission_type': 'edit'}],
#                    'users': []}},
#  'lookml': {'folder_id': 'lookml',
#             'name': 'LookML Dashboards',
#             'parent_id': None,
#             'content_metadata_id': None,
#             'personal': False,
#             'child_count': 0}}
